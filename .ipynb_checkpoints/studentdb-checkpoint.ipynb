# %%
import pandas as pd
import mysql.connector

conn = mysql.connector.connect(
    host='localhost',
    user='root',
    password='apeksha@1108',
    database='student_db'
)

# %%
students_df = pd.read_sql("SELECT * FROM Students;", conn)
grades_df   = pd.read_sql("SELECT * FROM Grades;", conn)
attendance_df = pd.read_sql("SELECT * FROM Attendance;", conn)
# Out:
# C:\Users\apeks\AppData\Local\Temp\ipykernel_25004\4217666932.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   students_df = pd.read_sql("SELECT * FROM Students;", conn)
# C:\Users\apeks\AppData\Local\Temp\ipykernel_25004\4217666932.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   grades_df   = pd.read_sql("SELECT * FROM Grades;", conn)
# C:\Users\apeks\AppData\Local\Temp\ipykernel_25004\4217666932.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
# ...

# %%
display(students_df.head())
# Out:
#    StudentID  RollNo FirstName LastName Gender  Year Department
# 0          1  BCA001     Aarav    Patil      M     3        BCA
# 1          2  BCA002      Diya    Menon      F     3        BCA
# 2          3  BCA003     Rohan    Verma      M     3        BCA
# 3          4  BCA004     Sneha   Pillai      F     3        BCA
# 4          5  BCA005    Aditya   Sharma      M     3        BCA

# %%
display(grades_df.head())
# Out:
#    GradeID  StudentID  CourseID  MarksObtained    ExamDate
# 0        1          1         1           72.0  2025-04-10
# 1        2          2         1           48.0  2025-04-10
# 2        3          3         1           55.0  2025-04-10
# 3        4          4         1           33.0  2025-04-10
# 4        5          5         1           88.0  2025-04-10

# %%
display(attendance_df.head())
# Out:
#    AttendanceID  StudentID  CourseID  TotalClasses  ClassesAttended     Month
# 0             1          1         1            40               36  Apr-2025
# 1             2          2         1            40               20  Apr-2025
# 2             3          3         1            40               28  Apr-2025
# 3             4          4         1            40               12  Apr-2025
# 4             5          5         1            40               38  Apr-2025

# %% [markdown]
# ### Calculate attendance percentage

# %%
attendance_df['AttendancePercent'] = (
    (attendance_df['ClassesAttended'] / attendance_df['TotalClasses']) * 100
).round(2)

# %% [markdown]
# ### Calculate average marks per student

# %%
avg_marks = grades_df.groupby('StudentID')['MarksObtained'].mean().reset_index()
avg_marks.columns = ['StudentID', 'AvgMarks']

# %% [markdown]
# ### Merge everything into one clean dataset

# %%
merged_df = (
    students_df
    .merge(avg_marks, on='StudentID', how='left')
    .merge(attendance_df[['StudentID', 'AttendancePercent']], on='StudentID', how='left')
)

# %%
merged_df['Pass'] = (
    (merged_df['AvgMarks'] >= 40) &
    (merged_df['AttendancePercent'] >= 75)
).astype(int)

# %%
display(merged_df)
# Out:
#    StudentID  RollNo FirstName LastName Gender  Year Department  AvgMarks  \
# 0          1  BCA001     Aarav    Patil      M     3        BCA      83.5
# 1          2  BCA002      Diya    Menon      F     3        BCA      48.0
# 2          3  BCA003     Rohan    Verma      M     3        BCA      55.0
# 3          4  BCA004     Sneha   Pillai      F     3        BCA      33.0
# 4          5  BCA005    Aditya   Sharma      M     3        BCA      88.0
# 5          6  BCA006     Meera     Nair      F     3        BCA      60.0
# 6          7  BCA007    Vikram      Das      M     3        BCA      25.0
# 7          8  BCA008    Ishita      Rao      F     3        BCA      79.0
# 8          9  BCA009     Karan   Kapoor      M     3        BCA      46.0
# 9         10  BCA010     Nisha    Patel      F     3        BCA      69.0
#
#    AttendancePercent  Pass
# 0               90.0     1
# 1               50.0     0
# 2               70.0     0
# 3               30.0     0
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import matplotlib.pyplot as plt
import seaborn as sns

# %%
X = merged_df[['AttendancePercent', 'AvgMarks']]
y = merged_df['Pass']

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42, stratify=y
)

# %%
lr = LogisticRegression()
lr.fit(X_train, y_train)

y_pred_lr = lr.predict(X_test)

print("Accuracy:", round(accuracy_score(y_test, y_pred_lr), 3))
print("\nClassification Report:\n", classification_report(y_test, y_pred_lr))

# Confusion matrix
cm_lr = confusion_matrix(y_test, y_pred_lr)
sns.heatmap(cm_lr, annot=True, fmt='d', cmap='Purples')
plt.title("Logistic Regression Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()
# Out:
# Accuracy: 1.0
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         2
#            1       1.00      1.00      1.00         1
#
#     accuracy                           1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(
    data=merged_df,
    x='AttendancePercent',
    y='AvgMarks',
    hue='Pass',           # color by pass/fail
    palette={1: 'yellow', 0: 'red'},
    s=100
)
plt.title('Attendance vs Average Marks (Green = Pass, Red = Fail)')
plt.xlabel('Attendance (%)')
plt.ylabel('Average Marks')
plt.grid(True)
plt.show()

# %% [raw]
# The scatter plot clearly shows a positive relationship between attendance and marks. Students with
# attendance above 75% and marks above 40 are mostly in the “Pass” (yellow) region, while those with low attendance or marks fall in the “Fail”
# (red) region. This confirms that both academic performance and consistent class participation contribute to passing rates.

# %%
plt.figure(figsize=(7,5))
sns.histplot(data=merged_df, x='AvgMarks', hue='Pass', bins=8, palette={1:'yellow',0:'red'}, kde=True)
plt.title('Distribution of Marks for Pass/Fail Students')
plt.xlabel('Average Marks')
plt.ylabel('Count of Students')
plt.show()

# %% [raw]
# The histogram indicates that most failing students have marks concentrated below 40, whereas passing students’
# marks are distributed between 60 and 90. There is a clear separation between the two groups.

# %%
plt.figure(figsize=(6,5))
sns.barplot(
    data=merged_df,
    x='Pass',
    y='AttendancePercent',
    hue='Pass',
    palette={0:'red',1:'yellow'},
    legend=False
)
plt.xticks([0,1], ['Fail', 'Pass'])
plt.title('Average Attendance of Pass vs Fail Students')
plt.xlabel('Status')
plt.ylabel('Average Attendance (%)')
plt.show()

# %% [raw]
# The average attendance for passing students is around 85–95%, while failing students average below 60%.
# This reinforces the importance of regular class attendance in achieving better grades.
